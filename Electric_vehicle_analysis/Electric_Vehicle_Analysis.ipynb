# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("/content/Electric_Vehicle_Population_Data.csv")

# %%
df
# Out:
#        VIN (1-10)     County              City State  Postal Code  Model Year  \
# 0      5UXTA6C05P     Yakima            Yakima    WA      98903.0        2023
# 1      5YJRE11B48        NaN               NaN    BC          NaN        2008
# 2      5YJSA1E24G       King           Seattle    WA      98103.0        2016
# 3      1N4AZ1CP5J       King         Shoreline    WA      98177.0        2018
# 4      5YJ3E1EA6J     Island        Coupeville    WA      98239.0        2018
# ...           ...        ...               ...   ...          ...         ...
# 85615  WBY7Z2C58J       King  Lake Forest Park    WA      98155.0        2018
# 85616  5YJ3E1EBXL      Clark         Vancouver    WA      98661.0        2020
# 85617  7SAYGDEE4N  Snohomish           Bothell    WA      98012.0        2022
# 85618  1G1FZ6S01P       King       Federal Way    WA      98023.0        2023
# 85619  3MW39FS06P       King           Seattle    WA      98109.0        2023
#
# ...

# %%
df.describe()
# Out:
#         Postal Code    Model Year  Electric Range      Base MSRP  \
# count  85617.000000  85620.000000    85620.000000   85620.000000
# mean   98137.060210   2020.140096       66.251939    1282.260628
# std     2582.258759      3.001692       95.602883    8881.117542
# min     1730.000000   1997.000000        0.000000       0.000000
# 25%    98042.000000   2018.000000        0.000000       0.000000
# 50%    98116.000000   2021.000000       17.000000       0.000000
# 75%    98335.000000   2023.000000       87.000000       0.000000
# max    99577.000000   2024.000000      337.000000  184400.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract      Counties  \
# count          85401.000000    8.562000e+04       8.561700e+04  85404.000000
# mean              30.103055    2.127168e+08       5.295962e+10   2933.712859
# std               14.807791    8.042875e+07       1.766496e+09    453.748481
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85620 entries, 0 to 85619
# Data columns (total 20 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   VIN (1-10)                                         85620 non-null  object
#  1   County                                             85617 non-null  object
#  2   City                                               85617 non-null  object
#  3   State                                              85620 non-null  object
#  4   Postal Code                                        85617 non-null  float64
#  5   Model Year                                         85620 non-null  int64
#  6   Make                                               85620 non-null  object
#  7   Model                                              85620 non-null  object
# ...

# %%
df.shape
# Out:
# (85620, 20)

# %%
df.isnull().sum()/len(df)*100
# Out:
# VIN (1-10)                                           0.000000
# County                                               0.003504
# City                                                 0.003504
# State                                                0.000000
# Postal Code                                          0.003504
# Model Year                                           0.000000
# Make                                                 0.000000
# Model                                                0.000000
# Electric Vehicle Type                                0.000000
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0.000000
# Electric Range                                       0.000000
# Base MSRP                                            0.000000
# Legislative District                                 0.255781
# DOL Vehicle ID                                       0.000000
# Vehicle Location                                     0.005840
# ...

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   3
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 219
# DOL Vehicle ID                                         0
# Vehicle Location                                       5
# Electric Utility                                       3
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# VIN (1-10)                                            object
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                         int64
# Base MSRP                                              int64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                      object
# ...

# %% [markdown]
# filling categorical data

# %%
for i in df:
    if df[i].dtypes=="O":
        df[i]= df[i].fillna(df[i].mode()[0])
    elif df[i].dtypes=="int64":
        df[i]= df[i].fillna(df[i].mean())
    elif df[i].dtypes=="float64":
        df[i]= df[i].fillna(df[i].mean())

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# ...

# %% [markdown]
# Exploratory Data Analysis

# %%
df
# Out:
#        VIN (1-10)     County              City State  Postal Code  Model Year  \
# 0      5UXTA6C05P     Yakima            Yakima    WA  98903.00000        2023
# 1      5YJRE11B48       King           Seattle    BC  98137.06021        2008
# 2      5YJSA1E24G       King           Seattle    WA  98103.00000        2016
# 3      1N4AZ1CP5J       King         Shoreline    WA  98177.00000        2018
# 4      5YJ3E1EA6J     Island        Coupeville    WA  98239.00000        2018
# ...           ...        ...               ...   ...          ...         ...
# 85615  WBY7Z2C58J       King  Lake Forest Park    WA  98155.00000        2018
# 85616  5YJ3E1EBXL      Clark         Vancouver    WA  98661.00000        2020
# 85617  7SAYGDEE4N  Snohomish           Bothell    WA  98012.00000        2022
# 85618  1G1FZ6S01P       King       Federal Way    WA  98023.00000        2023
# 85619  3MW39FS06P       King           Seattle    WA  98109.00000        2023
#
# ...

# %% [markdown]
# # INSIGHTS

# %%
df['Electric Vehicle Type'].value_counts()
# Out:
# Electric Vehicle Type
# Battery Electric Vehicle (BEV)            66895
# Plug-in Hybrid Electric Vehicle (PHEV)    18725
# Name: count, dtype: int64

# %%
dist_year=df.groupby(['Model Year','Electric Vehicle Type'])['VIN (1-10)'].count().unstack()
dist_year
# Out:
# Electric Vehicle Type  Battery Electric Vehicle (BEV)  \
# Model Year
# 1997                                              1.0
# 1998                                              1.0
# 1999                                              3.0
# 2000                                              5.0
# 2002                                              1.0
# 2008                                             11.0
# 2010                                             18.0
# 2011                                            376.0
# 2012                                            417.0
# 2013                                           1618.0
# 2014                                           1005.0
# 2015                                           1952.0
# 2016                                           2102.0
# 2017                                           2508.0
# 2018                                           5662.0
# 2019                                           4844.0
# ...

# %%
dist_year=df.groupby(['Model Year','Electric Vehicle Type'])['VIN (1-10)'].count().unstack()
dist_year.plot(kind="bar",stacked=True,figsize=(10,5))
plt.title("Electric Vehicle Type Over the Years");
plt.xlabel("Years")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # country vs electric vehicle type

# %%
ev=df['State'].value_counts().reset_index()
ev.columns = ['State', 'Count']
plt.figure(figsize=(10, 6))
plt.subplot(1,2,1)
plt.title("State with highest EV concentration")
ax=sns.barplot(data=ev[ev['State'] =='WA'],x='State',y='Count')
plt.xlabel('State')
plt.ylabel('Number of Vehicles')

top_5= ev[(ev['State']!="WA")].nlargest(10,'Count')
plt.subplot(1,2,2)
sns.barplot(data=top_5, x="State",y='Count')
plt.title("State with highest EV concentration ['excluding WA']")
plt.xlabel('State')
plt.ylabel('Number of Vehicles');

# %% [markdown]
# # Top CAR MAKERS

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
ev=df['Make'].value_counts().reset_index()
ev.columns=['Make','Count']
plt.title("Top 10 Maker of ev")
plt.xlabel('Make')
plt.ylabel('Number of Vehicles');
ev=ev.nlargest(10,"Count")
sns.barplot(data=ev, x="Make",y='Count');


plt.subplot(1,2,2)
plt.title("Top 10 Model of ev %")
ev=ev.nlargest(10,"Count")
plt.pie(ev.Count, labels=ev.Make.unique(), autopct="%0.0f%%");

# %% [markdown]
# # top 10 EV models

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
ev=df['Model'].value_counts().reset_index()
ev.columns=['Model','Count']
plt.title("Top 10 Model of ev")
plt.xlabel('Model')
plt.ylabel('Number of Vehicles');
ev=ev.nlargest(10,"Count")
sns.barplot(data=ev, x="Model",y='Count');


plt.subplot(1,2,2)
ev=ev.nlargest(10,"Count")
plt.title("Top 10 Model of ev %")
plt.pie(ev.Count, labels=ev.Model.unique(), autopct="%0.0f%%");

# %% [markdown]
# # Company Dominates the Market – Bar Chart

# %%
# Count EV makes
make_count = df['Make'].value_counts().head(10)

plt.figure(figsize=(10,5))
sns.barplot(x=make_count.index, y=make_count.values)
plt.title("Top 10 EV Manufacturers")
plt.ylabel("Number of Vehicles")
plt.xlabel("Make")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # EV Growth Trend (Model Year)

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, x="Model Year", order=sorted(df["Model Year"].unique()))
plt.title("EV Growth Trend by Model Year")
plt.xlabel("Model Year")
plt.ylabel("Count of EVs")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Geographic Concentration (County + City)

# %% [markdown]
# COUNTRY

# %%
county_counts = df["County"].value_counts().head(10)

plt.figure(figsize=(10,5))
sns.barplot(x=county_counts.index, y=county_counts.values)
plt.title("Top 10 Counties by EV Count")
plt.xlabel("County")
plt.ylabel("EV Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# CITY

# %%
city_counts = df["City"].value_counts().head(10)

plt.figure(figsize=(10,5))
sns.barplot(x=city_counts.index, y=city_counts.values)
plt.title("Top 10 Cities by EV Count")
plt.xlabel("City")
plt.ylabel("EV Count")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # EV Type Distribution (BEV vs PHEV)

# %%
ev_type = df["Electric Vehicle Type"].value_counts()

plt.figure(figsize=(6,6))
plt.pie(ev_type.values, labels=ev_type.index, autopct='%1.1f%%', startangle=140)
plt.title("EV Type Distribution (BEV vs PHEV)")
plt.show()

# %% [markdown]
# # Clean Alternative Fuel Eligibility

# %%
eligibility = df["Clean Alternative Fuel Vehicle (CAFV) Eligibility"].value_counts()

plt.figure(figsize=(8,5))
sns.barplot(x=eligibility.index, y=eligibility.values)
plt.xticks(rotation=45)
plt.title("Clean Alternative Fuel Vehicle Eligibility")
plt.ylabel("Number of Vehicles")
plt.show()

# %% [markdown]
# # Electric Range Patterns

# %% [markdown]
# Average Electric Range

# %%
df["Electric Range"].describe()
# Out:
# count    85620.000000
# mean        66.251939
# std         95.602883
# min          0.000000
# 25%          0.000000
# 50%         17.000000
# 75%         87.000000
# max        337.000000
# Name: Electric Range, dtype: float64

# %% [markdown]
# Electric Range Distribution

# %%
plt.figure(figsize=(10,5))
sns.histplot(df["Electric Range"], bins=30, kde=True)
plt.title("Distribution of Electric Range")
plt.xlabel("Electric Range (Miles)")
plt.show()

# %% [markdown]
# Model Year vs Electric Range

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df, x="Model Year", y="Electric Range")
plt.title("Electric Range by Model Year")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Vehicle Age & Replacement Cycle

# %%
import datetime

current_year = datetime.datetime.now().year

df["Vehicle Age"] = current_year - df["Model Year"]

plt.figure(figsize=(10,5))
sns.histplot(df["Vehicle Age"], bins=20, kde=True)
plt.title("Distribution of EV Vehicle Age")
plt.xlabel("Age (Years)")
plt.show()

# %% [markdown]
# # How many EVs are older than 5 years?

# %%
older_ev = df[df["Vehicle Age"] > 5].shape[0]
total_ev = df.shape[0]
percentage = older_ev / total_ev * 100

print(f"EVs older than 5 years: {older_ev} ({percentage:.2f}%)")
# Out:
# EVs older than 5 years: 29887 (34.91%)
